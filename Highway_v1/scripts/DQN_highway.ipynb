# %%
import gymnasium as gym
import highway_env
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.noise import NormalActionNoise

# Create the environment
env = gym.make("highway-v1")

# Wrap the environment
env.reset()
# Out:
# (array([[ 1.        ,  0.91575617,  0.75      ,  0.3125    ,  0.        ],
#         [ 1.        ,  0.10728545, -0.25      , -0.02721141,  0.        ],
#         [ 1.        ,  0.21219198,  0.        , -0.04746236,  0.        ],
#         [ 1.        ,  0.31268114, -0.75      , -0.03372091,  0.        ],
#         [ 1.        ,  0.42327598, -0.25      , -0.0387785 ,  0.        ]],
#        dtype=float32),
#  {'speed': 25,
#   'crashed': False,
#   'action': 3,
#   'rewards': {'collision_reward': 0.0,
#    'right_lane_reward': 1.0,
#    'high_speed_reward': 0.8333333333333334,
#    'on_road_reward': 1.0,
#    'reverse_reward': 0.0,
#    'stopping_penalty': 0}})

# %%
# Create the SAC model
model = DQN(
    "MlpPolicy",
    env,
    policy_kwargs=dict(net_arch=[256, 256]),
    learning_rate=5e-4,
    buffer_size=15000,
    learning_starts=200,
    batch_size=32,
    gamma=0.8,
    train_freq=1,
    gradient_steps=1,
    target_update_interval=50,
    verbose=1,
    tensorboard_log="highway_dqn",
)

# Train the model
model.learn(total_timesteps=15000,tb_log_name = 'DQN_1')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn\DQN_1_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 8.29     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5        |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5        |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4        |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 9.4      |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4        |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.41     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4        |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 211      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.45     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4        |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 252      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.228    |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.93     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4        |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 315      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.138    |
# |    n_updates        | 114      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.06     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4        |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 366      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0986   |
# |    n_updates        | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 9.88     |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4        |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 445      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.272    |
# |    n_updates        | 244      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4        |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 481      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.343    |
# |    n_updates        | 280      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4        |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 534      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 333      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4        |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 600      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.166    |
# |    n_updates        | 399      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4        |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 620      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.21     |
# |    n_updates        | 419      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4        |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 723      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.283    |
# |    n_updates        | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4        |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 808      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 607      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4        |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 877      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.193    |
# |    n_updates        | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4        |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 947      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.327    |
# |    n_updates        | 746      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.357    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4        |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 1016     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4        |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 1114     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.309    |
# |    n_updates        | 913      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4        |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 1172     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.396    |
# |    n_updates        | 971      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4        |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 1332     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.195    |
# |    n_updates        | 1131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.0696   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4        |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 1469     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.119    |
# |    n_updates        | 1268     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4        |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 1563     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.123    |
# |    n_updates        | 1362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4        |
# |    time_elapsed     | 347      |
# |    total_timesteps  | 1654     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0101   |
# |    n_updates        | 1453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4        |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 1814     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.3      |
# |    n_updates        | 1613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4        |
# |    time_elapsed     | 405      |
# |    total_timesteps  | 1934     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.21     |
# |    n_updates        | 1733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4        |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 2001     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0141   |
# |    n_updates        | 1800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4        |
# |    time_elapsed     | 447      |
# |    total_timesteps  | 2134     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.293    |
# |    n_updates        | 1933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4        |
# |    time_elapsed     | 474      |
# |    total_timesteps  | 2264     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.206    |
# |    n_updates        | 2063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4        |
# |    time_elapsed     | 495      |
# |    total_timesteps  | 2365     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0926   |
# |    n_updates        | 2164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4        |
# |    time_elapsed     | 513      |
# |    total_timesteps  | 2447     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00543  |
# |    n_updates        | 2246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4        |
# |    time_elapsed     | 535      |
# |    total_timesteps  | 2555     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.182    |
# |    n_updates        | 2354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4        |
# |    time_elapsed     | 569      |
# |    total_timesteps  | 2715     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.112    |
# |    n_updates        | 2514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4        |
# |    time_elapsed     | 595      |
# |    total_timesteps  | 2839     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.105    |
# |    n_updates        | 2638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4        |
# |    time_elapsed     | 608      |
# |    total_timesteps  | 2904     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00299  |
# |    n_updates        | 2703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4        |
# |    time_elapsed     | 624      |
# |    total_timesteps  | 2979     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 2778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4        |
# |    time_elapsed     | 657      |
# |    total_timesteps  | 3138     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.386    |
# |    n_updates        | 2937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4        |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 3247     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.177    |
# |    n_updates        | 3046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4        |
# |    time_elapsed     | 704      |
# |    total_timesteps  | 3360     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00266  |
# |    n_updates        | 3159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4        |
# |    time_elapsed     | 716      |
# |    total_timesteps  | 3414     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 3213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4        |
# |    time_elapsed     | 727      |
# |    total_timesteps  | 3467     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 3266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.6     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4        |
# |    time_elapsed     | 757      |
# |    total_timesteps  | 3608     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 3407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4        |
# |    time_elapsed     | 784      |
# |    total_timesteps  | 3741     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.29     |
# |    n_updates        | 3540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4        |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 3870     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 3669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.5     |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4        |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 4024     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0764   |
# |    n_updates        | 3823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.8     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4        |
# |    time_elapsed     | 860      |
# |    total_timesteps  | 4109     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.106    |
# |    n_updates        | 3908     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4        |
# |    time_elapsed     | 877      |
# |    total_timesteps  | 4190     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00778  |
# |    n_updates        | 3989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.7     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4        |
# |    time_elapsed     | 907      |
# |    total_timesteps  | 4334     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 4133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4        |
# |    time_elapsed     | 935      |
# |    total_timesteps  | 4471     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.178    |
# |    n_updates        | 4270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.7     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4        |
# |    time_elapsed     | 958      |
# |    total_timesteps  | 4581     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.116    |
# |    n_updates        | 4380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4        |
# |    time_elapsed     | 991      |
# |    total_timesteps  | 4741     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0947   |
# |    n_updates        | 4540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4        |
# |    time_elapsed     | 1017     |
# |    total_timesteps  | 4867     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00524  |
# |    n_updates        | 4666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 25.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4        |
# |    time_elapsed     | 1051     |
# |    total_timesteps  | 5027     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0749   |
# |    n_updates        | 4826     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4        |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 5187     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.105    |
# |    n_updates        | 4986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4        |
# |    time_elapsed     | 1110     |
# |    total_timesteps  | 5315     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.101    |
# |    n_updates        | 5114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 26.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4        |
# |    time_elapsed     | 1132     |
# |    total_timesteps  | 5417     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00545  |
# |    n_updates        | 5216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4        |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 5558     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0061   |
# |    n_updates        | 5357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 4        |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 5645     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0965   |
# |    n_updates        | 5444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 4        |
# |    time_elapsed     | 1204     |
# |    total_timesteps  | 5758     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0019   |
# |    n_updates        | 5557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 4        |
# |    time_elapsed     | 1223     |
# |    total_timesteps  | 5853     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 5652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | 26.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 4        |
# |    time_elapsed     | 1258     |
# |    total_timesteps  | 6007     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 5806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 4        |
# |    time_elapsed     | 1288     |
# |    total_timesteps  | 6149     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00737  |
# |    n_updates        | 5948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 4        |
# |    time_elapsed     | 1306     |
# |    total_timesteps  | 6238     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0943   |
# |    n_updates        | 6037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 4        |
# |    time_elapsed     | 1334     |
# |    total_timesteps  | 6375     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 6174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | 27.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4        |
# |    time_elapsed     | 1361     |
# |    total_timesteps  | 6502     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00919  |
# |    n_updates        | 6301     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.3     |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4        |
# |    time_elapsed     | 1380     |
# |    total_timesteps  | 6594     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.212    |
# |    n_updates        | 6393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | 28       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 4        |
# |    time_elapsed     | 1413     |
# |    total_timesteps  | 6754     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0102   |
# |    n_updates        | 6553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.1     |
# |    ep_rew_mean      | 27.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 4        |
# |    time_elapsed     | 1432     |
# |    total_timesteps  | 6848     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0929   |
# |    n_updates        | 6647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.2     |
# |    ep_rew_mean      | 26.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 4        |
# |    time_elapsed     | 1441     |
# |    total_timesteps  | 6889     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00583  |
# |    n_updates        | 6688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 26.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 4        |
# |    time_elapsed     | 1460     |
# |    total_timesteps  | 6980     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.328    |
# |    n_updates        | 6779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 4        |
# |    time_elapsed     | 1481     |
# |    total_timesteps  | 7080     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.313    |
# |    n_updates        | 6879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.2     |
# |    ep_rew_mean      | 26.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 4        |
# |    time_elapsed     | 1509     |
# |    total_timesteps  | 7209     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 7008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 4        |
# |    time_elapsed     | 1536     |
# |    total_timesteps  | 7341     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00554  |
# |    n_updates        | 7140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 4        |
# |    time_elapsed     | 1569     |
# |    total_timesteps  | 7501     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 7300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.8     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 4        |
# |    time_elapsed     | 1602     |
# |    total_timesteps  | 7658     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0066   |
# |    n_updates        | 7457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 4        |
# |    time_elapsed     | 1632     |
# |    total_timesteps  | 7804     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.284    |
# |    n_updates        | 7603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4        |
# |    time_elapsed     | 1659     |
# |    total_timesteps  | 7931     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00182  |
# |    n_updates        | 7730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4        |
# |    time_elapsed     | 1680     |
# |    total_timesteps  | 8033     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.116    |
# |    n_updates        | 7832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4        |
# |    time_elapsed     | 1713     |
# |    total_timesteps  | 8193     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00193  |
# |    n_updates        | 7992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4        |
# |    time_elapsed     | 1730     |
# |    total_timesteps  | 8275     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00465  |
# |    n_updates        | 8074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4        |
# |    time_elapsed     | 1754     |
# |    total_timesteps  | 8386     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 8185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4        |
# |    time_elapsed     | 1780     |
# |    total_timesteps  | 8508     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0107   |
# |    n_updates        | 8307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4        |
# |    time_elapsed     | 1806     |
# |    total_timesteps  | 8634     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00538  |
# |    n_updates        | 8433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 26.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4        |
# |    time_elapsed     | 1826     |
# |    total_timesteps  | 8729     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.111    |
# |    n_updates        | 8528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 4        |
# |    time_elapsed     | 1848     |
# |    total_timesteps  | 8835     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00865  |
# |    n_updates        | 8634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 4        |
# |    time_elapsed     | 1869     |
# |    total_timesteps  | 8938     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00902  |
# |    n_updates        | 8737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 4        |
# |    time_elapsed     | 1896     |
# |    total_timesteps  | 9066     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0053   |
# |    n_updates        | 8865     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4        |
# |    time_elapsed     | 1913     |
# |    total_timesteps  | 9149     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 8948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4        |
# |    time_elapsed     | 1939     |
# |    total_timesteps  | 9273     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0883   |
# |    n_updates        | 9072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4        |
# |    time_elapsed     | 1970     |
# |    total_timesteps  | 9423     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.149    |
# |    n_updates        | 9222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4        |
# |    time_elapsed     | 2004     |
# |    total_timesteps  | 9583     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00414  |
# |    n_updates        | 9382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 4        |
# |    time_elapsed     | 2032     |
# |    total_timesteps  | 9718     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00333  |
# |    n_updates        | 9517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# ...
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 10943    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00355  |
# |    n_updates        | 10742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 4        |
# |    time_elapsed     | 2318     |
# |    total_timesteps  | 11082    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.112    |
# |    n_updates        | 10881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | 28       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 4        |
# |    time_elapsed     | 2342     |
# |    total_timesteps  | 11198    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00576  |
# |    n_updates        | 10997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | 28       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 4        |
# |    time_elapsed     | 2376     |
# |    total_timesteps  | 11358    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00232  |
# |    n_updates        | 11157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.1     |
# |    ep_rew_mean      | 28.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 4        |
# |    time_elapsed     | 2402     |
# |    total_timesteps  | 11482    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00803  |
# |    n_updates        | 11281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.9     |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 4        |
# |    time_elapsed     | 2422     |
# |    total_timesteps  | 11580    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 11379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.7     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 4        |
# |    time_elapsed     | 2442     |
# |    total_timesteps  | 11676    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00462  |
# |    n_updates        | 11475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.4     |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 4        |
# |    time_elapsed     | 2462     |
# |    total_timesteps  | 11771    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00417  |
# |    n_updates        | 11570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 4        |
# |    time_elapsed     | 2495     |
# |    total_timesteps  | 11931    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.107    |
# |    n_updates        | 11730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 4        |
# |    time_elapsed     | 2529     |
# |    total_timesteps  | 12091    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00346  |
# |    n_updates        | 11890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 4        |
# |    time_elapsed     | 2557     |
# |    total_timesteps  | 12227    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.187    |
# |    n_updates        | 12026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 4        |
# |    time_elapsed     | 2591     |
# |    total_timesteps  | 12376    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00604  |
# |    n_updates        | 12175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 4        |
# |    time_elapsed     | 2620     |
# |    total_timesteps  | 12504    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0115   |
# |    n_updates        | 12303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 29.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 4        |
# |    time_elapsed     | 2642     |
# |    total_timesteps  | 12609    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00912  |
# |    n_updates        | 12408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 4        |
# |    time_elapsed     | 2675     |
# |    total_timesteps  | 12769    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00222  |
# |    n_updates        | 12568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 4        |
# |    time_elapsed     | 2702     |
# |    total_timesteps  | 12898    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 12697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 4        |
# |    time_elapsed     | 2730     |
# |    total_timesteps  | 13029    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00262  |
# |    n_updates        | 12828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 4        |
# |    time_elapsed     | 2761     |
# |    total_timesteps  | 13176    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0036   |
# |    n_updates        | 12975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.6     |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 4        |
# |    time_elapsed     | 2795     |
# |    total_timesteps  | 13336    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.276    |
# |    n_updates        | 13135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.6     |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 4        |
# |    time_elapsed     | 2829     |
# |    total_timesteps  | 13496    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00457  |
# |    n_updates        | 13295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.3     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 4        |
# |    time_elapsed     | 2856     |
# |    total_timesteps  | 13620    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.105    |
# |    n_updates        | 13419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 4        |
# |    time_elapsed     | 2885     |
# |    total_timesteps  | 13755    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0378   |
# |    n_updates        | 13554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 4        |
# |    time_elapsed     | 2908     |
# |    total_timesteps  | 13863    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00369  |
# |    n_updates        | 13662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 4        |
# |    time_elapsed     | 2937     |
# |    total_timesteps  | 13998    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 13797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 4        |
# |    time_elapsed     | 2967     |
# |    total_timesteps  | 14133    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00293  |
# |    n_updates        | 13932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.3     |
# |    ep_rew_mean      | 29.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 4        |
# |    time_elapsed     | 2997     |
# |    total_timesteps  | 14273    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00338  |
# |    n_updates        | 14072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 4        |
# |    time_elapsed     | 3029     |
# |    total_timesteps  | 14424    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 14223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.6     |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 4        |
# |    time_elapsed     | 3059     |
# |    total_timesteps  | 14562    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 14361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 4        |
# |    time_elapsed     | 3084     |
# |    total_timesteps  | 14676    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00389  |
# |    n_updates        | 14475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 4        |
# |    time_elapsed     | 3116     |
# |    total_timesteps  | 14823    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00892  |
# |    n_updates        | 14622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.9     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 4        |
# |    time_elapsed     | 3148     |
# |    total_timesteps  | 14973    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00725  |
# |    n_updates        | 14772    |
# ----------------------------------

# %%
model.learn(total_timesteps=5000, tb_log_name="DQN_1",reset_num_timesteps=False)
# Out:
# Logging to highway_dqn\DQN_1_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | 30       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 0        |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 30111    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0884   |
# |    n_updates        | 29910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | 30       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 0        |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 30239    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00237  |
# |    n_updates        | 30038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 0        |
# |    time_elapsed     | 473      |
# |    total_timesteps  | 30370    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0102   |
# |    n_updates        | 30169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 30.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 0        |
# |    time_elapsed     | 688      |
# |    total_timesteps  | 30530    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 30329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | 30.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 0        |
# |    time_elapsed     | 921      |
# |    total_timesteps  | 30690    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 30489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 0        |
# |    time_elapsed     | 1010     |
# |    total_timesteps  | 30782    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00178  |
# |    n_updates        | 30581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.6     |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 0        |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 30906    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0201   |
# |    n_updates        | 30705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 0        |
# |    time_elapsed     | 1249     |
# |    total_timesteps  | 31020    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.092    |
# |    n_updates        | 30819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | 30.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 0        |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 31130    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00339  |
# |    n_updates        | 30929    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 0        |
# |    time_elapsed     | 1673     |
# |    total_timesteps  | 31253    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0028   |
# |    n_updates        | 31052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.3     |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 0        |
# |    time_elapsed     | 1929     |
# |    total_timesteps  | 31381    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00182  |
# |    n_updates        | 31180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34       |
# |    ep_rew_mean      | 30       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 0        |
# |    time_elapsed     | 2154     |
# |    total_timesteps  | 31509    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00508  |
# |    n_updates        | 31308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | 30.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 0        |
# |    time_elapsed     | 2263     |
# |    total_timesteps  | 31615    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00632  |
# |    n_updates        | 31414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 0        |
# |    time_elapsed     | 2278     |
# |    total_timesteps  | 31683    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00685  |
# |    n_updates        | 31482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.3     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 0        |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 31814    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00343  |
# |    n_updates        | 31613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 0        |
# |    time_elapsed     | 2334     |
# |    total_timesteps  | 31937    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0109   |
# |    n_updates        | 31736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 0        |
# |    time_elapsed     | 2364     |
# |    total_timesteps  | 32068    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0116   |
# |    n_updates        | 31867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.7     |
# |    ep_rew_mean      | 28.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 0        |
# |    time_elapsed     | 2391     |
# |    total_timesteps  | 32189    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0976   |
# |    n_updates        | 31988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.4     |
# |    ep_rew_mean      | 28.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 0        |
# |    time_elapsed     | 2415     |
# |    total_timesteps  | 32296    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.105    |
# |    n_updates        | 32095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.1     |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 0        |
# |    time_elapsed     | 2444     |
# |    total_timesteps  | 32424    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0049   |
# |    n_updates        | 32223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 1        |
# |    time_elapsed     | 2473     |
# |    total_timesteps  | 32551    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00559  |
# |    n_updates        | 32350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 1        |
# |    time_elapsed     | 2510     |
# |    total_timesteps  | 32711    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00395  |
# |    n_updates        | 32510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 1        |
# |    time_elapsed     | 2537     |
# |    total_timesteps  | 32827    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0588   |
# |    n_updates        | 32626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 1        |
# |    time_elapsed     | 2573     |
# |    total_timesteps  | 32987    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0115   |
# |    n_updates        | 32786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.4     |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 1        |
# |    time_elapsed     | 2603     |
# |    total_timesteps  | 33123    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0145   |
# |    n_updates        | 32922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.7     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 1        |
# |    time_elapsed     | 2639     |
# |    total_timesteps  | 33283    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00784  |
# |    n_updates        | 33082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.9     |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 1        |
# |    time_elapsed     | 2672     |
# |    total_timesteps  | 33429    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0278   |
# |    n_updates        | 33228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 1        |
# |    time_elapsed     | 2704     |
# |    total_timesteps  | 33572    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00531  |
# |    n_updates        | 33371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | 28       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 1        |
# |    time_elapsed     | 2729     |
# |    total_timesteps  | 33686    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00553  |
# |    n_updates        | 33485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.4     |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 1        |
# |    time_elapsed     | 2761     |
# |    total_timesteps  | 33828    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00622  |
# |    n_updates        | 33627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.1     |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 1        |
# |    time_elapsed     | 2797     |
# |    total_timesteps  | 33988    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00517  |
# |    n_updates        | 33787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 1        |
# |    time_elapsed     | 2820     |
# |    total_timesteps  | 34088    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00483  |
# |    n_updates        | 33887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.1     |
# |    ep_rew_mean      | 28.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 1        |
# |    time_elapsed     | 2852     |
# |    total_timesteps  | 34234    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00719  |
# |    n_updates        | 34033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 1        |
# |    time_elapsed     | 2888     |
# |    total_timesteps  | 34394    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0107   |
# |    n_updates        | 34193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 1        |
# |    time_elapsed     | 2924     |
# |    total_timesteps  | 34554    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0069   |
# |    n_updates        | 34353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 1        |
# |    time_elapsed     | 2952     |
# |    total_timesteps  | 34677    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0587   |
# |    n_updates        | 34476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 1        |
# |    time_elapsed     | 2980     |
# |    total_timesteps  | 34801    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0144   |
# |    n_updates        | 34600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 1        |
# |    time_elapsed     | 3010     |
# |    total_timesteps  | 34929    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 34728    |
# ----------------------------------

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import highway_env
from IPython.display import clear_output, display

# modewl = TD3.load("td3_highway_model")
# # Create the environment
# env = gym.make("highway-v1",render_mode="rgb_array")

# # Configure the environment for continuous actions
# env.unwrapped.configure({
#     "action": {"type": "ContinuousAction"},
#     "duration": 40,  # [s]
#     "lanes_count": 4,
#     "vehicles_count": 50,
#     "controlled_vehicles": 1,
#     "initial_lane_id": None,
#     "ego_spacing": 2,
#     "collision_reward": -1,  
#     "right_lane_reward": 0.4,
#     "high_speed_reward": 0.8,
#     "lane_change_reward": 0,
#     "reward_speed_range": [10, 30],
#     "reverse_reward": -2,
#     "stopping_penalty": -2,
#     "normalize_reward": True,
#     "offroad_terminal": False,
# })

# Reset the environment
obs, info = env.reset()
done = False

# Run the simulation loop
while not done:
    # Sample a random action
    #action = env.action_space.sample()
    action, _ = model.predict(obs, deterministic=False)

    # Take a step in the environment
    obs, reward, done, truncated, info = env.step(action)


    # Render the environment as an image
    frame = env.render()

    # Display the rendered frame
    plt.imshow(frame)
    plt.axis("off")
    clear_output(wait=True)  # Clear the previous frame
    display(plt.gcf())       # Display the current frame

    # Check if the episode is done
    done = truncated


# Close the environment
env.close()

# %%
model = DQN.load("DQN_highwayv1")

# %%
# Save the trained model
model.save("DQN_highwayv1")

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

timestep_rewards = []
cumulative_rewards = []
episode_lengths = []
crashes = 0  # Track number of crashes
timesteps = []

# Run the trained model for testing
current_timestep = 0
total_episodes = 100

print("Testing DQN Model on Highway-v0 Environment")

for episode in range(total_episodes):  
    done = truncated = False
    obs, info = env.reset()
    total_reward = 0
    episode_length = 0
    episode_crash = False  # Track crash per episode

    while not (done or truncated):
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(action)

        # Accumulate rewards and track timesteps
        total_reward += reward
        current_timestep += 1
        episode_length += 1
        env.render()

        # Check if a crash occurred
        if info.get("crashed", False):
            episode_crash = True

        # Log timestep data
        timestep_rewards.append(reward)
        timesteps.append(current_timestep)

    # Update statistics
    cumulative_rewards.append(total_reward)
    episode_lengths.append(episode_length)
    crashes += int(episode_crash)  # Count if the episode had a crash

    print(f"Episode {episode + 1}: Reward = {total_reward:.2f}, Length = {episode_length} timesteps, Crash: {episode_crash}")

env.close()

# Compute statistics
mean_reward = sum(cumulative_rewards) / total_episodes
mean_episode_length = sum(episode_lengths) / total_episodes
crash_rate = crashes / total_episodes  # Percentage of episodes with crashes

print(f"\nMean Reward: {mean_reward:.2f}")
print(f"Mean Episode Length: {mean_episode_length:.2f}")
print(f"Crash Rate: {crash_rate:.2%}")

# Cumulative Rewards Plot
episodes = range(1, len(cumulative_rewards) + 1)
plt.figure(figsize=(10, 6))
plt.plot(episodes, cumulative_rewards, marker='o', label="Cumulative Reward per Episode")
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("Model Performance Over Episodes")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Testing TD3 Model on Highway-v0 Environment
# Episode 1: Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 2: Reward = 34.74, Length = 40 timesteps, Crash: False
# Episode 3: Reward = 36.44, Length = 40 timesteps, Crash: False
# Episode 4: Reward = 35.71, Length = 40 timesteps, Crash: False
# Episode 5: Reward = 35.51, Length = 40 timesteps, Crash: False
# Episode 6: Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 7: Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 8: Reward = 35.04, Length = 40 timesteps, Crash: False
# Episode 9: Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 10: Reward = 37.10, Length = 40 timesteps, Crash: False
# Episode 11: Reward = 36.06, Length = 40 timesteps, Crash: False
# Episode 12: Reward = 33.58, Length = 40 timesteps, Crash: False
# Episode 13: Reward = 34.80, Length = 40 timesteps, Crash: False
# Episode 14: Reward = 2.12, Length = 3 timesteps, Crash: True
# Episode 15: Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 16: Reward = 35.53, Length = 40 timesteps, Crash: False
# Episode 17: Reward = 36.13, Length = 40 timesteps, Crash: False
# Episode 18: Reward = 36.98, Length = 40 timesteps, Crash: False
# Episode 19: Reward = 34.61, Length = 40 timesteps, Crash: False
# Episode 20: Reward = 36.13, Length = 40 timesteps, Crash: False
# Episode 21: Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 22: Reward = 35.52, Length = 40 timesteps, Crash: False
# Episode 23: Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 24: Reward = 7.73, Length = 9 timesteps, Crash: True
# Episode 25: Reward = 33.76, Length = 40 timesteps, Crash: False
# Episode 26: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 27: Reward = 32.37, Length = 40 timesteps, Crash: False
# Episode 28: Reward = 2.90, Length = 4 timesteps, Crash: True
# Episode 29: Reward = 1.89, Length = 3 timesteps, Crash: True
# Episode 30: Reward = 34.31, Length = 40 timesteps, Crash: False
# Episode 31: Reward = 35.04, Length = 40 timesteps, Crash: False
# Episode 32: Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 33: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 34: Reward = 7.18, Length = 9 timesteps, Crash: True
# Episode 35: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 36: Reward = 36.56, Length = 40 timesteps, Crash: False
# Episode 37: Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 38: Reward = 36.44, Length = 40 timesteps, Crash: False
# Episode 39: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 40: Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 41: Reward = 34.55, Length = 40 timesteps, Crash: False
# Episode 42: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 43: Reward = 34.98, Length = 40 timesteps, Crash: False
# Episode 44: Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 45: Reward = 36.62, Length = 40 timesteps, Crash: False
# Episode 46: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 47: Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 48: Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 49: Reward = 36.19, Length = 40 timesteps, Crash: False
# Episode 50: Reward = 23.33, Length = 27 timesteps, Crash: True
# Episode 51: Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 52: Reward = 35.04, Length = 40 timesteps, Crash: False
# Episode 53: Reward = 2.09, Length = 3 timesteps, Crash: True
# Episode 54: Reward = 35.41, Length = 40 timesteps, Crash: False
# Episode 55: Reward = 32.80, Length = 40 timesteps, Crash: False
# Episode 56: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 57: Reward = 35.77, Length = 40 timesteps, Crash: False
# Episode 58: Reward = 35.41, Length = 40 timesteps, Crash: False
# Episode 59: Reward = 35.71, Length = 40 timesteps, Crash: False
# Episode 60: Reward = 35.95, Length = 40 timesteps, Crash: False
# Episode 61: Reward = 35.77, Length = 40 timesteps, Crash: False
# Episode 62: Reward = 35.41, Length = 40 timesteps, Crash: False
# Episode 63: Reward = 36.19, Length = 40 timesteps, Crash: False
# Episode 64: Reward = 30.56, Length = 40 timesteps, Crash: False
# Episode 65: Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 66: Reward = 36.74, Length = 40 timesteps, Crash: False
# Episode 67: Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 68: Reward = 36.98, Length = 40 timesteps, Crash: False
# Episode 69: Reward = 35.95, Length = 40 timesteps, Crash: False
# Episode 70: Reward = 36.62, Length = 40 timesteps, Crash: False
# Episode 71: Reward = 35.53, Length = 40 timesteps, Crash: False
# Episode 72: Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 73: Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 74: Reward = 35.65, Length = 40 timesteps, Crash: False
# Episode 75: Reward = 36.38, Length = 40 timesteps, Crash: False
# Episode 76: Reward = 35.65, Length = 40 timesteps, Crash: False
# Episode 77: Reward = 34.43, Length = 40 timesteps, Crash: False
# Episode 78: Reward = 32.98, Length = 40 timesteps, Crash: False
# Episode 79: Reward = 32.99, Length = 39 timesteps, Crash: True
# Episode 80: Reward = 34.31, Length = 40 timesteps, Crash: False
# Episode 81: Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 82: Reward = 36.62, Length = 40 timesteps, Crash: False
# Episode 83: Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 84: Reward = 35.47, Length = 40 timesteps, Crash: False
# Episode 85: Reward = 35.47, Length = 40 timesteps, Crash: False
# Episode 86: Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 87: Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 88: Reward = 35.65, Length = 40 timesteps, Crash: False
# Episode 89: Reward = 34.07, Length = 40 timesteps, Crash: False
# Episode 90: Reward = 36.19, Length = 40 timesteps, Crash: False
# Episode 91: Reward = 34.92, Length = 40 timesteps, Crash: False
# Episode 92: Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 93: Reward = 5.73, Length = 7 timesteps, Crash: True
# Episode 94: Reward = 35.21, Length = 40 timesteps, Crash: False
# Episode 95: Reward = 34.92, Length = 40 timesteps, Crash: False
# Episode 96: Reward = 36.50, Length = 40 timesteps, Crash: False
# Episode 97: Reward = 35.53, Length = 40 timesteps, Crash: False
# Episode 98: Reward = 36.07, Length = 40 timesteps, Crash: False
# Episode 99: Reward = 36.56, Length = 40 timesteps, Crash: False
# Episode 100: Reward = 35.77, Length = 40 timesteps, Crash: False
#
# Mean Reward: 33.05
# Mean Episode Length: 37.44
# Crash Rate: 9.00%

# %%
# # Load the pre-trained DQN model
# model = DQN.load("DQN_highwayv1")

# # Create the highway-v1 environment
# env = gym.make("highway-v1", render_mode="rgb_array")  # Ensure highway-v1 is registered

# Number of test episodes
n_episodes = 50

# Exponential delay parameters
scale = 1.2  # Mean delay
max_delay = 2  # Maximum delay in seconds

# Tracking performance metrics
cumulative_rewards = []
episode_lengths = []
crashes = 0  # Track number of crashes

# Run testing loop
for episode in range(n_episodes):
    obs, info = env.reset()
    total_reward = 0
    done = False
    episode_length = 0
    episode_crash = False  # Track crash per episode

    # Generate a random delay from an exponential distribution, capped at max_delay
    random_delay = min(np.random.exponential(scale), max_delay)

    while not done:
        action, _ = model.predict(obs, deterministic=True)

        # Apply the computation delay before executing the action
        env.unwrapped.elapse(random_delay)

        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        episode_length += 1
        done = terminated or truncated

        # Check if a crash occurred
        if info.get("crashed", False):
            episode_crash = True

    # Update statistics
    cumulative_rewards.append(total_reward)
    episode_lengths.append(episode_length)
    crashes += int(episode_crash)  # Count if the episode had a crash

    print(f"Episode {episode + 1}: Delay = {random_delay:.2f}s, "
          f"Total Reward = {total_reward:.2f}, Length = {episode_length} timesteps, Crash: {episode_crash}")

env.close()

# Compute statistics
mean_reward = sum(cumulative_rewards) / n_episodes
mean_episode_length = sum(episode_lengths) / n_episodes
crash_rate = crashes / n_episodes  # Percentage of episodes with crashes

print(f"\nMean Reward: {mean_reward:.2f}")
print(f"Mean Episode Length: {mean_episode_length:.2f}")
print(f"Crash Rate: {crash_rate:.2%}")
# Out:
# Episode 1: Delay = 1.17s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 2: Delay = 2.00s, Total Reward = 1.01, Length = 2 timesteps, Crash: True
# Episode 3: Delay = 0.44s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 4: Delay = 0.97s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 5: Delay = 1.59s, Total Reward = 3.76, Length = 5 timesteps, Crash: True
# Episode 6: Delay = 0.11s, Total Reward = 35.65, Length = 40 timesteps, Crash: False
# Episode 7: Delay = 0.08s, Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 8: Delay = 0.75s, Total Reward = 33.95, Length = 40 timesteps, Crash: False
# Episode 9: Delay = 0.51s, Total Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 10: Delay = 2.00s, Total Reward = 33.46, Length = 40 timesteps, Crash: False
# Episode 11: Delay = 1.05s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 12: Delay = 2.00s, Total Reward = 12.83, Length = 15 timesteps, Crash: True
# Episode 13: Delay = 1.39s, Total Reward = 1.05, Length = 2 timesteps, Crash: True
# Episode 14: Delay = 2.00s, Total Reward = 34.12, Length = 40 timesteps, Crash: False
# Episode 15: Delay = 0.84s, Total Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 16: Delay = 1.48s, Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 17: Delay = 1.15s, Total Reward = 35.52, Length = 40 timesteps, Crash: False
# Episode 18: Delay = 0.09s, Total Reward = 35.41, Length = 40 timesteps, Crash: False
# Episode 19: Delay = 1.02s, Total Reward = 34.61, Length = 40 timesteps, Crash: False
# Episode 20: Delay = 0.28s, Total Reward = 10.53, Length = 13 timesteps, Crash: True
# Episode 21: Delay = 1.45s, Total Reward = 35.71, Length = 40 timesteps, Crash: False
# Episode 22: Delay = 2.00s, Total Reward = 33.70, Length = 40 timesteps, Crash: False
# Episode 23: Delay = 1.01s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 24: Delay = 2.00s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 25: Delay = 0.93s, Total Reward = 34.43, Length = 40 timesteps, Crash: False
# Episode 26: Delay = 2.00s, Total Reward = 33.46, Length = 40 timesteps, Crash: False
# Episode 27: Delay = 0.90s, Total Reward = 35.04, Length = 40 timesteps, Crash: False
# Episode 28: Delay = 0.60s, Total Reward = 33.52, Length = 40 timesteps, Crash: False
# Episode 29: Delay = 1.84s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 30: Delay = 0.60s, Total Reward = 35.52, Length = 40 timesteps, Crash: False
# Episode 31: Delay = 2.00s, Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 32: Delay = 0.59s, Total Reward = 1.12, Length = 2 timesteps, Crash: True
# Episode 33: Delay = 0.08s, Total Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 34: Delay = 0.26s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 35: Delay = 1.01s, Total Reward = 33.82, Length = 40 timesteps, Crash: False
# Episode 36: Delay = 0.95s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 37: Delay = 0.55s, Total Reward = 1.19, Length = 2 timesteps, Crash: True
# Episode 38: Delay = 0.60s, Total Reward = 34.91, Length = 40 timesteps, Crash: False
# Episode 39: Delay = 1.31s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 40: Delay = 0.05s, Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 41: Delay = 0.37s, Total Reward = 19.64, Length = 25 timesteps, Crash: True
# Episode 42: Delay = 2.00s, Total Reward = 2.10, Length = 3 timesteps, Crash: True
# Episode 43: Delay = 0.78s, Total Reward = 35.52, Length = 40 timesteps, Crash: False
# Episode 44: Delay = 0.27s, Total Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 45: Delay = 2.00s, Total Reward = 34.97, Length = 40 timesteps, Crash: False
# Episode 46: Delay = 0.63s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 47: Delay = 0.08s, Total Reward = 34.80, Length = 40 timesteps, Crash: False
# Episode 48: Delay = 0.20s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 49: Delay = 1.08s, Total Reward = 35.77, Length = 40 timesteps, Crash: False
# Episode 50: Delay = 0.13s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
#
# Mean Reward: 29.79
# Mean Episode Length: 34.18
# Crash Rate: 18.00%

# %%
# # Load the pre-trained DQN model
# model = DQN.load("DQN_highwayv1")

# # Create the highway-v1 environment
# env = gym.make("highway-v1", render_mode="rgb_array")  # Ensure highway-v1 is registered

# Number of test episodes
n_episodes = 50

# Exponential delay parameters
scale = 1.2  # Mean delay
max_delay = 2  # Maximum delay in seconds

# Tracking performance metrics
cumulative_rewards = []
episode_lengths = []
crashes = 0  # Track number of crashes

# Run testing loop
for episode in range(n_episodes):
    obs, info = env.reset()
    total_reward = 0
    done = False
    episode_length = 0
    episode_crash = False  # Track crash per episode

    # Generate a random delay from an exponential distribution, capped at max_delay
    random_delay = min(np.random.exponential(scale), max_delay)

    while not done:
        action, _ = model.predict(obs, deterministic=True)

        # Apply the computation delay before executing the action
        env.unwrapped.elapse(random_delay)

        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        episode_length += 1
        done = terminated or truncated

        # Check if a crash occurred
        if info.get("crashed", False):
            episode_crash = True

    # Update statistics
    cumulative_rewards.append(total_reward)
    episode_lengths.append(episode_length)
    crashes += int(episode_crash)  # Count if the episode had a crash

    print(f"Episode {episode + 1}: Delay = {random_delay:.2f}s, "
          f"Total Reward = {total_reward:.2f}, Length = {episode_length} timesteps, Crash: {episode_crash}")

env.close()

# Compute statistics
mean_reward = sum(cumulative_rewards) / n_episodes
mean_episode_length = sum(episode_lengths) / n_episodes
crash_rate = crashes / n_episodes  # Percentage of episodes with crashes

print(f"\nMean Reward: {mean_reward:.2f}")
print(f"Mean Episode Length: {mean_episode_length:.2f}")
print(f"Crash Rate: {crash_rate:.2%}")
# Out:
# Episode 1: Delay = 0.59s, Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 2: Delay = 0.34s, Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 3: Delay = 0.46s, Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 4: Delay = 0.70s, Total Reward = 35.53, Length = 40 timesteps, Crash: False
# Episode 5: Delay = 0.31s, Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 6: Delay = 0.23s, Total Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 7: Delay = 1.86s, Total Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 8: Delay = 0.11s, Total Reward = 36.01, Length = 40 timesteps, Crash: False
# Episode 9: Delay = 1.56s, Total Reward = 1.10, Length = 2 timesteps, Crash: True
# Episode 10: Delay = 0.45s, Total Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 11: Delay = 2.00s, Total Reward = 10.16, Length = 14 timesteps, Crash: True
# Episode 12: Delay = 0.42s, Total Reward = 36.13, Length = 40 timesteps, Crash: False
# Episode 13: Delay = 0.70s, Total Reward = 35.58, Length = 40 timesteps, Crash: False
# Episode 14: Delay = 0.27s, Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 15: Delay = 0.24s, Total Reward = 23.40, Length = 31 timesteps, Crash: True
# Episode 16: Delay = 0.22s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 17: Delay = 0.90s, Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 18: Delay = 0.11s, Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 19: Delay = 2.00s, Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 20: Delay = 0.83s, Total Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 21: Delay = 0.29s, Total Reward = 34.92, Length = 40 timesteps, Crash: False
# Episode 22: Delay = 1.83s, Total Reward = 6.69, Length = 8 timesteps, Crash: True
# Episode 23: Delay = 2.00s, Total Reward = 1.10, Length = 2 timesteps, Crash: True
# Episode 24: Delay = 0.06s, Total Reward = 16.81, Length = 20 timesteps, Crash: True
# Episode 25: Delay = 2.00s, Total Reward = 34.84, Length = 40 timesteps, Crash: False
# Episode 26: Delay = 0.13s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 27: Delay = 2.00s, Total Reward = 0.97, Length = 2 timesteps, Crash: True
# Episode 28: Delay = 1.97s, Total Reward = 5.35, Length = 6 timesteps, Crash: True
# Episode 29: Delay = 0.84s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 30: Delay = 2.00s, Total Reward = 1.10, Length = 2 timesteps, Crash: True
# Episode 31: Delay = 0.69s, Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 32: Delay = 0.34s, Total Reward = 9.08, Length = 11 timesteps, Crash: True
# Episode 33: Delay = 0.70s, Total Reward = 36.19, Length = 40 timesteps, Crash: False
# Episode 34: Delay = 0.08s, Total Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 35: Delay = 0.65s, Total Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 36: Delay = 1.11s, Total Reward = 33.88, Length = 40 timesteps, Crash: False
# Episode 37: Delay = 1.94s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 38: Delay = 0.03s, Total Reward = 36.50, Length = 40 timesteps, Crash: False
# Episode 39: Delay = 0.05s, Total Reward = 30.74, Length = 40 timesteps, Crash: False
# Episode 40: Delay = 0.15s, Total Reward = 34.68, Length = 40 timesteps, Crash: False
# Episode 41: Delay = 2.00s, Total Reward = 2.12, Length = 3 timesteps, Crash: True
# Episode 42: Delay = 0.26s, Total Reward = 33.71, Length = 40 timesteps, Crash: False
# Episode 43: Delay = 0.20s, Total Reward = 35.03, Length = 40 timesteps, Crash: False
# Episode 44: Delay = 1.03s, Total Reward = 35.71, Length = 40 timesteps, Crash: False
# Episode 45: Delay = 2.00s, Total Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 46: Delay = 0.73s, Total Reward = 13.67, Length = 17 timesteps, Crash: True
# Episode 47: Delay = 0.11s, Total Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 48: Delay = 0.52s, Total Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 49: Delay = 0.65s, Total Reward = 1.97, Length = 3 timesteps, Crash: True
# Episode 50: Delay = 0.73s, Total Reward = 35.46, Length = 40 timesteps, Crash: False
#
# Mean Reward: 27.95
# Mean Episode Length: 32.02
# Crash Rate: 26.00%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Define metrics
metrics_main = ["Mean Reward", "Mean Episode Length"]
before_delay_main = [33.05, 37.44]  # Mean Reward, Episode Length (before delay)
after_delay_main = [27.95, 32.02]  # Mean Reward, Episode Length (after delay)

metrics_crash = ["Crash Rate"]
before_delay_crash = [9.00]  # Crash Rate (before delay)
after_delay_crash = [26.00]  # Crash Rate (after delay)

# Set Seaborn style
sns.set_style("whitegrid")

# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# --- First Chart: Mean Reward & Episode Length ---
x = np.arange(len(metrics_main))  # Label positions
width = 0.35  # Bar width

bars1 = axes[0].bar(x - width/2, before_delay_main, width, label="Before Delay", color="#103463")
bars2 = axes[0].bar(x + width/2, after_delay_main, width, label="After Delay", color="#f3b6b3")

# Labels & Title
axes[0].set_title("Mean Reward & Episode Length", fontsize=14, fontweight="bold")
axes[0].set_xlabel("Metrics", fontsize=12)
axes[0].set_ylabel("Values", fontsize=12)
axes[0].set_xticks(x)
axes[0].set_xticklabels(metrics_main)
axes[0].legend()

# Show value labels on bars
def add_labels(bars, ax):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # Offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1, axes[0])
add_labels(bars2, axes[0])

# --- Second Chart: Crash Rate ---
x_crash = np.arange(len(metrics_crash))  # Label positions
crash_width = 0.3  # Narrower bar width for crash rate

bars3 = axes[1].bar(x_crash - crash_width, before_delay_crash, crash_width, label="Before Delay", color="#103463")
bars4 = axes[1].bar(x_crash + crash_width, after_delay_crash, crash_width, label="After Delay", color="#f3b6b3")

# Labels & Title
axes[1].set_title("Crash Rate", fontsize=14, fontweight="bold")
axes[1].set_xlabel("Metrics", fontsize=12)
axes[1].set_ylabel("Values (%)", fontsize=12)
axes[1].set_xticks(x_crash)
axes[1].set_xticklabels(metrics_crash)
axes[1].legend()

# Show value labels on bars
add_labels(bars3, axes[1])
add_labels(bars4, axes[1])

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import DQN

# Load the pre-trained DQN model
model = DQN.load("DQN_highwayv1")

# Create the highway-v1 environment
env = gym.make("highway-v1", render_mode="rgb_array")  # Ensure highway-v1 is registered

# Number of test episodes
n_episodes = 50

# Exponential delay parameters
scale = 1.2  # Mean delay
max_delay = 2  # Maximum delay in seconds

# Tracking performance metrics for both tests
cumulative_rewards_no_delay = []
cumulative_rewards_with_delay = []
episode_lengths_no_delay = []
episode_lengths_with_delay = []
crashes_no_delay = 0
crashes_with_delay = 0

# Run testing without delay
for episode in range(n_episodes):
    obs, info = env.reset()
    total_reward = 0
    done = False
    episode_length = 0
    episode_crash = False  # Track crash per episode

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        episode_length += 1
        done = terminated or truncated

        # Check if a crash occurred
        if info.get("crashed", False):
            episode_crash = True

    cumulative_rewards_no_delay.append(total_reward)
    episode_lengths_no_delay.append(episode_length)
    crashes_no_delay += int(episode_crash)

    print(f"Episode {episode + 1} (No Delay): Total Reward = {total_reward:.2f}, Length = {episode_length} timesteps, Crash: {episode_crash}")

# Run testing with delay
for episode in range(n_episodes):
    obs, info = env.reset()
    total_reward = 0
    done = False
    episode_length = 0
    episode_crash = False

    # Generate a random delay from an exponential distribution, capped at max_delay
    random_delay = min(np.random.exponential(scale), max_delay)

    while not done:
        action, _ = model.predict(obs, deterministic=True)

        # Apply the computation delay before executing the action
        env.unwrapped.elapse(random_delay)

        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        episode_length += 1
        done = terminated or truncated

        # Check if a crash occurred
        if info.get("crashed", False):
            episode_crash = True

    cumulative_rewards_with_delay.append(total_reward)
    episode_lengths_with_delay.append(episode_length)
    crashes_with_delay += int(episode_crash)

    print(f"Episode {episode + 1} (With Delay): Delay = {random_delay:.2f}s, Total Reward = {total_reward:.2f}, Length = {episode_length} timesteps, Crash: {episode_crash}")

env.close()

# Compute statistics
mean_reward_no_delay = sum(cumulative_rewards_no_delay) / n_episodes
mean_reward_with_delay = sum(cumulative_rewards_with_delay) / n_episodes
mean_episode_length_no_delay = sum(episode_lengths_no_delay) / n_episodes
mean_episode_length_with_delay = sum(episode_lengths_with_delay) / n_episodes
crash_rate_no_delay = crashes_no_delay / n_episodes
crash_rate_with_delay = crashes_with_delay / n_episodes

print(f"\nWithout Delay - Mean Reward: {mean_reward_no_delay:.2f}, Mean Episode Length: {mean_episode_length_no_delay:.2f}, Crash Rate: {crash_rate_no_delay:.2%}")
print(f"With Delay - Mean Reward: {mean_reward_with_delay:.2f}, Mean Episode Length: {mean_episode_length_with_delay:.2f}, Crash Rate: {crash_rate_with_delay:.2%}")

# Plot the results
episodes = range(1, n_episodes + 1)

plt.figure(figsize=(14, 6))

# Cumulative Reward Comparison
plt.subplot(1, 2, 1)
plt.plot(episodes, cumulative_rewards_no_delay, marker='o', label="No Delay", color='#103463')
plt.plot(episodes, cumulative_rewards_with_delay, marker='x', label="With Delay", color='#f3b6b3')
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("Cumulative Reward Comparison")
plt.legend()
plt.grid(True)

# Episode Length Comparison
plt.subplot(1, 2, 2)
plt.plot(episodes, episode_lengths_no_delay, marker='o', label="No Delay", color='#103463')
plt.plot(episodes, episode_lengths_with_delay, marker='x', label="With Delay", color='#f3b6b3')
plt.xlabel("Episode")
plt.ylabel("Episode Length")
plt.title("Episode Length Comparison")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Episode 1 (No Delay): Total Reward = 36.56, Length = 40 timesteps, Crash: False
# Episode 2 (No Delay): Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 3 (No Delay): Total Reward = 35.29, Length = 40 timesteps, Crash: False
# Episode 4 (No Delay): Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 5 (No Delay): Total Reward = 36.19, Length = 40 timesteps, Crash: False
# Episode 6 (No Delay): Total Reward = 35.47, Length = 40 timesteps, Crash: False
# Episode 7 (No Delay): Total Reward = 36.56, Length = 40 timesteps, Crash: False
# Episode 8 (No Delay): Total Reward = 35.71, Length = 40 timesteps, Crash: False
# Episode 9 (No Delay): Total Reward = 32.80, Length = 40 timesteps, Crash: False
# Episode 10 (No Delay): Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 11 (No Delay): Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 12 (No Delay): Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 13 (No Delay): Total Reward = 36.07, Length = 40 timesteps, Crash: False
# Episode 14 (No Delay): Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 15 (No Delay): Total Reward = 36.19, Length = 40 timesteps, Crash: False
# Episode 16 (No Delay): Total Reward = 36.01, Length = 40 timesteps, Crash: False
# Episode 17 (No Delay): Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 18 (No Delay): Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 19 (No Delay): Total Reward = 36.80, Length = 40 timesteps, Crash: False
# Episode 20 (No Delay): Total Reward = 35.53, Length = 40 timesteps, Crash: False
# Episode 21 (No Delay): Total Reward = 34.98, Length = 40 timesteps, Crash: False
# Episode 22 (No Delay): Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 23 (No Delay): Total Reward = 5.81, Length = 7 timesteps, Crash: True
# Episode 24 (No Delay): Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 25 (No Delay): Total Reward = 37.16, Length = 40 timesteps, Crash: False
# Episode 26 (No Delay): Total Reward = 34.67, Length = 40 timesteps, Crash: False
# Episode 27 (No Delay): Total Reward = 9.52, Length = 13 timesteps, Crash: True
# Episode 28 (No Delay): Total Reward = 35.35, Length = 40 timesteps, Crash: False
# Episode 29 (No Delay): Total Reward = 36.01, Length = 40 timesteps, Crash: False
# Episode 30 (No Delay): Total Reward = 35.46, Length = 40 timesteps, Crash: False
# Episode 31 (No Delay): Total Reward = 35.95, Length = 40 timesteps, Crash: False
# Episode 32 (No Delay): Total Reward = 27.09, Length = 31 timesteps, Crash: True
# Episode 33 (No Delay): Total Reward = 34.61, Length = 40 timesteps, Crash: False
# Episode 34 (No Delay): Total Reward = 1.92, Length = 3 timesteps, Crash: True
# Episode 35 (No Delay): Total Reward = 35.04, Length = 40 timesteps, Crash: False
# Episode 36 (No Delay): Total Reward = 20.78, Length = 23 timesteps, Crash: True
# Episode 37 (No Delay): Total Reward = 35.71, Length = 40 timesteps, Crash: False
# Episode 38 (No Delay): Total Reward = 35.89, Length = 40 timesteps, Crash: False
# Episode 39 (No Delay): Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 40 (No Delay): Total Reward = 33.64, Length = 40 timesteps, Crash: False
# Episode 41 (No Delay): Total Reward = 32.80, Length = 40 timesteps, Crash: False
# Episode 42 (No Delay): Total Reward = 34.01, Length = 40 timesteps, Crash: False
# Episode 43 (No Delay): Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 44 (No Delay): Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 45 (No Delay): Total Reward = 35.41, Length = 40 timesteps, Crash: False
# Episode 46 (No Delay): Total Reward = 34.43, Length = 40 timesteps, Crash: False
# Episode 47 (No Delay): Total Reward = 33.95, Length = 40 timesteps, Crash: False
# Episode 48 (No Delay): Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 49 (No Delay): Total Reward = 34.85, Length = 40 timesteps, Crash: False
# Episode 50 (No Delay): Total Reward = 35.03, Length = 40 timesteps, Crash: False
# Episode 1 (With Delay): Delay = 1.45s, Total Reward = 28.14, Length = 32 timesteps, Crash: True
# Episode 2 (With Delay): Delay = 0.55s, Total Reward = 35.53, Length = 40 timesteps, Crash: False
# Episode 3 (With Delay): Delay = 2.00s, Total Reward = 2.23, Length = 3 timesteps, Crash: True
# Episode 4 (With Delay): Delay = 0.44s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 5 (With Delay): Delay = 2.00s, Total Reward = 3.17, Length = 4 timesteps, Crash: True
# Episode 6 (With Delay): Delay = 0.07s, Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 7 (With Delay): Delay = 0.25s, Total Reward = 2.10, Length = 3 timesteps, Crash: True
# Episode 8 (With Delay): Delay = 1.00s, Total Reward = 1.14, Length = 2 timesteps, Crash: True
# Episode 9 (With Delay): Delay = 0.99s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 10 (With Delay): Delay = 0.08s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 11 (With Delay): Delay = 1.91s, Total Reward = 0.92, Length = 2 timesteps, Crash: True
# Episode 12 (With Delay): Delay = 0.96s, Total Reward = 2.70, Length = 4 timesteps, Crash: True
# Episode 13 (With Delay): Delay = 0.62s, Total Reward = 34.13, Length = 40 timesteps, Crash: False
# Episode 14 (With Delay): Delay = 1.93s, Total Reward = 34.49, Length = 40 timesteps, Crash: False
# Episode 15 (With Delay): Delay = 2.00s, Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 16 (With Delay): Delay = 2.00s, Total Reward = 34.73, Length = 40 timesteps, Crash: False
# Episode 17 (With Delay): Delay = 0.26s, Total Reward = 35.63, Length = 40 timesteps, Crash: False
# Episode 18 (With Delay): Delay = 0.12s, Total Reward = 36.37, Length = 40 timesteps, Crash: False
# Episode 19 (With Delay): Delay = 0.82s, Total Reward = 35.04, Length = 40 timesteps, Crash: False
# Episode 20 (With Delay): Delay = 0.21s, Total Reward = 35.10, Length = 40 timesteps, Crash: False
# Episode 21 (With Delay): Delay = 0.05s, Total Reward = 5.95, Length = 7 timesteps, Crash: True
# Episode 22 (With Delay): Delay = 0.49s, Total Reward = 34.92, Length = 40 timesteps, Crash: False
# Episode 23 (With Delay): Delay = 0.91s, Total Reward = 34.98, Length = 40 timesteps, Crash: False
# Episode 24 (With Delay): Delay = 2.00s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 25 (With Delay): Delay = 1.98s, Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 26 (With Delay): Delay = 2.00s, Total Reward = 35.77, Length = 40 timesteps, Crash: False
# Episode 27 (With Delay): Delay = 1.37s, Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 28 (With Delay): Delay = 0.32s, Total Reward = 35.28, Length = 40 timesteps, Crash: False
# Episode 29 (With Delay): Delay = 0.69s, Total Reward = 34.73, Length = 40 timesteps, Crash: False
# Episode 30 (With Delay): Delay = 1.08s, Total Reward = 35.77, Length = 40 timesteps, Crash: False
# Episode 31 (With Delay): Delay = 0.37s, Total Reward = 33.82, Length = 40 timesteps, Crash: False
# Episode 32 (With Delay): Delay = 1.01s, Total Reward = 34.85, Length = 40 timesteps, Crash: False
# Episode 33 (With Delay): Delay = 1.22s, Total Reward = 36.31, Length = 40 timesteps, Crash: False
# Episode 34 (With Delay): Delay = 0.50s, Total Reward = 35.59, Length = 40 timesteps, Crash: False
# Episode 35 (With Delay): Delay = 1.82s, Total Reward = 33.40, Length = 40 timesteps, Crash: False
# Episode 36 (With Delay): Delay = 1.39s, Total Reward = 34.61, Length = 40 timesteps, Crash: False
# Episode 37 (With Delay): Delay = 2.00s, Total Reward = 34.36, Length = 40 timesteps, Crash: False
# Episode 38 (With Delay): Delay = 0.42s, Total Reward = 35.34, Length = 40 timesteps, Crash: False
# Episode 39 (With Delay): Delay = 1.25s, Total Reward = 34.19, Length = 40 timesteps, Crash: False
# Episode 40 (With Delay): Delay = 2.00s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 41 (With Delay): Delay = 0.31s, Total Reward = 2.22, Length = 3 timesteps, Crash: True
# Episode 42 (With Delay): Delay = 0.42s, Total Reward = 35.16, Length = 40 timesteps, Crash: False
# Episode 43 (With Delay): Delay = 0.15s, Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 44 (With Delay): Delay = 2.00s, Total Reward = 35.40, Length = 40 timesteps, Crash: False
# Episode 45 (With Delay): Delay = 1.09s, Total Reward = 35.83, Length = 40 timesteps, Crash: False
# Episode 46 (With Delay): Delay = 2.00s, Total Reward = 0.39, Length = 1 timesteps, Crash: True
# Episode 47 (With Delay): Delay = 0.19s, Total Reward = 35.22, Length = 40 timesteps, Crash: False
# Episode 48 (With Delay): Delay = 1.92s, Total Reward = 4.89, Length = 6 timesteps, Crash: True
# Episode 49 (With Delay): Delay = 0.54s, Total Reward = 9.02, Length = 11 timesteps, Crash: True
# Episode 50 (With Delay): Delay = 1.40s, Total Reward = 7.51, Length = 9 timesteps, Crash: True
#
# Without Delay - Mean Reward: 33.09, Mean Episode Length: 37.54, Crash Rate: 10.00%
# With Delay - Mean Reward: 27.41, Mean Episode Length: 31.34, Crash Rate: 26.00%

# %%
plt.figure(figsize=(14, 6))

# Cumulative Reward Comparison
plt.subplot(1, 2, 1)
plt.plot(episodes, cumulative_rewards_no_delay, marker='o', label="No Delay", color='#103463')
plt.plot(episodes, cumulative_rewards_with_delay, marker='x', label="With Delay", color='#f3b6b3')
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("Cumulative Reward Comparison")
plt.legend()
plt.grid(True)

# Episode Length Comparison
plt.subplot(1, 2, 2)
plt.plot(episodes, episode_lengths_no_delay, marker='o', label="No Delay", color='#103463')
plt.plot(episodes, episode_lengths_with_delay, marker='x', label="With Delay", color='#f3b6b3')
plt.xlabel("Episode")
plt.ylabel("Episode Length")
plt.title("Episode Length Comparison")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
